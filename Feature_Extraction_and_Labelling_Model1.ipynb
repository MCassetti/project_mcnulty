# %%
import scipy
from pathlib import Path
import pathlib
from scipy.io.wavfile import read
from scipy.signal import hann
from scipy import signal
from scipy.fftpack import rfft
import matplotlib.pyplot as plt
import librosa
import librosa.display
import numpy as np
from yaafelib import *
import pandas as pd
import math
import warnings
warnings.filterwarnings("ignore")

cols=['track_name','bpm','harmonic_rythmic_ratio',\
'spectral_centroid','spectral_flatness','count_delta_above_mean',\
'ratio_above_rmse_mean','max_rmse','mean_rms','mean_zcr','liked']
df = pd.DataFrame(columns=cols)

# %%
def set_output(artist):
 
    path = pathlib.Path("~/Music/" + artist + "/*.mp3").expanduser()
    parts = path.parts[1:] if path.is_absolute() else path.parts
    return pathlib.Path(path.root).glob(str(pathlib.Path("").joinpath(*parts)))

def count_rmse_above_mean(rmse):
    lower_count = 0
    upper_count = 0
    for e in rmse:
        if e > np.mean(rmse): #arbitrarily chosen, will tune later
            upper_count+=1
        else:
            lower_count +=1
    return upper_count/lower_count

def count_delta_above_mean(rmse):
    dyn_change = 0
    for i in range(len(rmse)-3):
        diff = rmse[i+3]-rmse[i]
        if diff > np.mean(rmse):
            dyn_change += 1
    return dyn_change

# %%
def harmonic_ratio(signal):
    ratios = []
    y_harmonic, y_percussive = librosa.effects.hpss(signal)
    if len(y_harmonic)== len(y_percussive):
        for i in range(len(y_harmonic)):
            if y_harmonic[i] > 0 and y_percussive[i] > 0: #tgety 
                ratios.append(y_harmonic[i]/y_percussive[i])
    else:
        print('lenghts not idenitcal')        
    return np.median(ratios)
    
def extract_features(signal):

    return [
        np.mean(librosa.feature.zero_crossing_rate(signal)),
        np.mean(librosa.feature.rmse(signal)[0]),
        np.max(librosa.feature.rmse(signal)[0]),
        count_rmse_above_mean(librosa.feature.rmse(signal)[0]),
        count_delta_above_mean(librosa.feature.rmse(signal)[0]),
        np.mean(librosa.feature.spectral_flatness(signal)),
        np.mean(librosa.feature.spectral_centroid(signal)),
        
    ]
def other_features(X,sample_rate): # will do RNN after I do SVM, LR, and DT
    cqt = np.mean(librosa.amplitude_to_db(librosa.cqt(y, sr=sr), ref=np.max).T,axis=axis)
    stft = np.abs(librosa.stft(X))
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),
    sr=sample_rate).T,axis=0)
    rmse = np.mean(librosa.feature.rmse(S=stft,sr=sample_rate).T,axis=0)
    return cqt,mfccs,chroma,mel,contrast,tonnetz,rmse

# %%
# %%time
# This takes way to long, consider compiling in C or parallel processing
# or some other method

artist = 'Metallica'
output = set_output(artist)

for p in output: 
    track_name = str(p).replace('/Users/mcassettix/Music/' + artist + '/','')
    print(track_name)
    try:
        y_total, sr = librosa.load(p) 
    except:
        print('loading issue, skipping track',p)
        continue
    
    #Sample each track multiple times to increase samples
    #Take 30 second slices of a song, rounded down 
    times = librosa.frames_to_time(np.arange(len(y_total)))
    if  times[-1] > 30: #standarizing length to 2 minutes
        max_time = len(y_total)/sr
        num_slices = math.floor(max_time/30) 
        hop_length = num_slices * sr
        max_x = num_slices*30*sr        
    else:
        print('Warning: you need pick a time range')
        print('skipping track ',p)
        continue 
    frames = list(range(hop_length,max_x, hop_length))
 
    for index in range(len(frames)-1):
        y = y_total[frames[index]:frames[index + 1]]
        tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)
        #print('Estimated tempo: {:.2f} beats per minute'.format(tempo))
        features = extract_features(y)
        features.append(harmonic_ratio(y))
        features.append(tempo)
        features.append(track_name)
        features.reverse()
        features.append(artist)
        newrow = np.transpose(features).reshape(1,-1)
        df = pd.DataFrame(newrow.reshape(1,-1),columns=cols).append(df, ignore_index=True)
# Out:
# 06 - Live At Wembley Stadium London 1.mp3
# 02 - Wherever I May Roam.mp3
# 03 - Some Kind Of Monster.mp3
# 09 - Last Caress.mp3
# 05 - One.mp3
# 04 - Dirty Window.mp3
# 09 - Poor Twisted Me.mp3
# 11 - Low Man's Lyric.mp3
# 10 - Devil's Dance.mp3
# 05 - All Nightmare Long.mp3
# 15 - For Whom The Bell Tolls (Live).mp3
# 08 - The Judas Kiss.mp3
# 07 - Killing Time.mp3
# 10 - Purify.mp3
# 07 - Tuesday's Gone.mp3
# 10 - Prince Charming.mp3
# 05 - A) Last Caress; B) Green Hell.mp3
# 08 - Justice Medley.mp3
# 08 - One.mp3
# 10 - The Wait.mp3
# 12 - Attitude.mp3
# 05 - (Anesthesia) Pulling Teeth.mp3
# 03 - Sabbra Cadabra.mp3
# 08 - Nothing Else Matters.mp3
# 06 - Seek And Destroy.mp3
# 05 - Seek & Destroy.mp3
# 02 - The Call Of Ktulu.mp3
# 03 - Eye Of The Beholder.mp3
# 18 - Whiplash.mp3
# 10 - Last Caress.mp3
# 16 - Stone Dead Forever.mp3
# 06 - Harvester Of Sorrow.mp3
# 09 - Where The Wild Things Are.mp3
# 09 - Suicide & Redemption.mp3
# 17 - A) Prowler B) Run To The Hills.mp3
# 04 - Turn The Page.mp3
# 03 - For Whom The Bell Tolls.mp3
# 05 - Last Caress - Green Hell.mp3
# 05 - Invisible Kid.mp3
# 09 - Stone Cold Crazy.mp3
# 04 - Crash Course In Brain Surgery.mp3
# 02 - The Small Hours.mp3
# 01 - Ain't My Bitch.mp3
# 02 - Ride The Lightning.mp3
# 02 - Metallica - One (Demo).mp3
# 07 - The Frayed Ends Of Sanity.mp3
# 07 - Sad But True.mp3
# 03 - The House Jack Built.mp3
# 07 - Carpe Diem Baby.mp3
# 04 - Stone Cold Crazy.mp3
# 05 - Wherever I May Roam.mp3
# 04 - Welcome Home (Sanitarium).mp3
# 03 - The Wait.mp3
# 10 - Tuesday's Gone.mp3
# 10 - My Apocalypse.mp3
# 04 - One.mp3
# 03 - Devil's Dance.mp3
# 02 - 2 X 4.mp3
# 10 - Battery.mp3
# 08 - To Live Is To Die.mp3
# 13 - Harvester Of Sorrow (Live).mp3
# 17 - Too Late Too Late.mp3
# 05 - Stone Cold Crazy.mp3
# 09 - Whiskey In The Jar.mp3
# 03 - So What.mp3
# 03 - Am I Evil.mp3
# 14 - Damage Case.mp3
# 12 - Killing Time.mp3
# 07 - So What.mp3
# 01 - Through The Never.mp3
# 04 - Of Wolf And Man.mp3
# 06 - Cyanide.mp3
# 06 - Escape.mp3
# 12 - The Struggle Within.mp3
# 14 - The Outlaw Torn.mp3
# 04 - The Day That Never Comes.mp3
# 10 - Bleeding Me.mp3
# 07 - The Unforgiven.mp3
# 07 - The Four Horsemen.mp3
# 11 - Mama Said.mp3
# 03 - Harvester Of Sorrow.mp3
# 06 - Whiplash.mp3
# 12 - Last Caress.mp3
# 01 - That Was Just Your Life.mp3
# 11 - Crash Course In Brain Surgery.mp3
# 07 - The Unforgiven III.mp3
# 14 - Sad But True (Live).mp3
# 04 - Blitzkrieg.mp3
# 01 - The Ecstacy Of Gold.mp3
# 07 - Mercyful Fate.mp3
# 11 - The More I See.mp3
# 15 - Damage Case.mp3
# 07 - Phantom Lord.mp3
# 07 - Orion (Instrumental).mp3
# 08 - No Leaf Clover.mp3
# 03 - The Four Horsemen.mp3
# 01 - Metallica - One.mp3
# 12 - Thorn Within.mp3
# 02 - For Whom The Bell Tolls.mp3
# 03 - Broken, Beat & Scarred.mp3
# 09 - Hero Of The Day.mp3
# 11 - Bleeding Me.mp3
# 06 - Of Wolf And Man.mp3
# 02 - Sad But True.mp3
# 01 - Creeping Death.mp3
# 01 - Low Man's Lyric.mp3
# 08 - Whiplash.mp3
# 02 - Master Of Puppets.mp3
# 06 - The Small Hours.mp3
# 05 - Nothing Else Matters.mp3
# 04 - Minus Human.mp3
# 08 - The Wait.mp3
# 03 - Motorbreath.mp3
# 11 - Green Hell.mp3
# 06 - Hero Of The Day.mp3
# 09 - Of Wolf And Man.mp3
# Sound 1.mp3
# 04 - Fade To Black.mp3
# 05 - Trapped Under Ice.mp3
# 02 - Creeping Death.mp3
# 10 - The God That Failed.mp3
# 11 - All Within My Hands.mp3
# 07 - Shoot Me Again.mp3
# 08 - A) Last Caress; B) Fade To Black.mp3
# 09 - The Small Hours.mp3
# 11 - Medley, Seek And Destroy, Fight Fire With Fire.mp3
# 04 - The Unforgiven Ii.mp3
# 08 - The Call Of Ktulu.mp3
# 07 - Creeping Death.mp3
# 08 - Sweet Amber.mp3
# 08 - Bad Seed.mp3
# 05 - The Thing That Should Not Be.mp3
# 05 - King Nothing.mp3
# 01 - Free Speech For The Dumb.mp3
# Sound 2.mp3
# 15 - Stone Dead Forever.mp3
# 01 - Battery.mp3
# 01 - Hit The Lights.mp3
# 02 - St. Anger.mp3
# 08 - No Remorse.mp3
# 09 - Fade To Black (Continued).mp3
# 04 - Master Of Puppets.mp3
# 09 - Crash Course In Brain Surgery.mp3
# 08 - Live At Wembley Stadium London 3.mp3
# 05 - (Welcome Home) Sanitarium.mp3
# Sound 3.mp3
# 04 - The Unforgiven.mp3
# 10 - Metal Militia.mp3
# 06 - My World.mp3
# 01 - Fuel.mp3
# 11 - So What.mp3
# 02 - Helpless.mp3
# 10 - Stone Cold Crazy.mp3
# 09 - Enter Sandman.mp3
# 10 - Am I Evil.mp3
# 08 - Damage, Inc..mp3
# 01 - Blackened.mp3
# 06 - Outlaw Torn.mp3
# 02 - It's Electric.mp3
# 13 - Fixxxer.mp3
# 04 - Leper Messiah.mp3
# 07 - Through The Never.mp3
# 11 - Battery.mp3
# 06 - Battery.mp3
# Sound 6.mp3
# 12 - Enter Sandman (Live).mp3
# Sound 4.mp3
# 06 - Am I Evil.mp3
# 03 - Fade To Black.mp3
# 07 - Blitzkrieg.mp3
# 05 - Helpless.mp3
# 01 - Frantic.mp3
# 10 - Wasting My Hate.mp3
# 03 - The Thing That Should Not Be.mp3
# 04 - Until It Sleeps.mp3
# 02 - The Memory Remains.mp3
# 06 - Leper Messiah.mp3
# Sound 5.mp3
# 03 - Metallica - One (Live).mp3
# 02 - Until It Sleeps.mp3
# 08 - Astronomy.mp3
# 02 - The Prince.mp3
# 03 - Master Of Puppets.mp3
# 04 - Jump In The Fire.mp3
# 04 - Last Caress.mp3
# 11 - My Friend Of Misery.mp3
# 08 - Breadfan.mp3
# 08 - Motorbreath.mp3
# 02 - The Four Horsemen.mp3
# 14 - Overkill.mp3
# 08 - Cure.mp3
# 04 - Poor Twisted Me.mp3
# 09 - Dyer's Eve.mp3
# 09 - The Prince.mp3
# 05 - Die, Die My Darling.mp3
# 09 - Solos (Bass  Guitar).mp3
# 08 - Helpless.mp3
# 07 - The Memory Remains.mp3
# 06 - Fuel.mp3
# 13 - Overkill.mp3
# 06 - Loverman.mp3
# 06 - Creeping Death.mp3
# 02 - The End Of The Line.mp3
# 13 - Green Hell.mp3
# 13 - Ronnie.mp3
# 07 - Bleeding Me.mp3
# 05 - Sad But True.mp3
# 07 - Live At Wembley Stadium London 2.mp3
# 06 - Killing Time.mp3
# 06 - Slither.mp3
# 06 - Don't Tread On Me.mp3
# 03 - Holier Than Thou.mp3
# 07 - Master Of Puppets.mp3
# 01 - Fight Fire With Fire.mp3
# 05 - The Shortest Straw.mp3
# 01 - Nothing Else Matters.mp3
# 09 - The Unnamed Feeling.mp3
# 01 - Helpless.mp3
# 16 - Whereever I May Roam.mp3
# 16 - Too Late Too Late.mp3
# 01 - Enter Sandman.mp3
# 09 - Seek & Destroy.mp3
# 05 - Disposable Heroes.mp3
# 05 - Better Than You.mp3
# 01 - Breadfan.mp3
# 02 - ...And Justice For All.mp3
# CPU times: user 9h 42min 8s, sys: 19min 42s, total: 10h 1min 50s
# Wall time: 6h 5min 5s

# %%
df.tail()
# Out:
#                                      track_name                 bpm  \
# 6323  06 - Live At Wembley Stadium London 1.mp3  135.99917763157896
# 6324  06 - Live At Wembley Stadium London 1.mp3        129.19921875
# 6325  06 - Live At Wembley Stadium London 1.mp3        129.19921875
# 6326  06 - Live At Wembley Stadium London 1.mp3        129.19921875
# 6327  06 - Live At Wembley Stadium London 1.mp3        129.19921875
#
#      harmonic_rythmic_ratio   spectral_centroid spectral_flatness  \
# 6323               2.012115   2743.487061452844       0.041087333
# 6324               2.053566   2396.664545732893       0.024036167
# 6325              1.9386886   2346.376283673442       0.022524519
# 6326              2.1696758   2262.935753709684       0.021709993
# 6327              2.7291753  2969.3739130557583        0.06191542
#
#      count_delta_above_mean ratio_above_rmse_mean    max_rmse     mean_rms  \
# 6323                      0    0.8735177865612648  0.22269402   0.16670083
# 6324                      0    0.9190283400809717  0.23766279   0.17079656
# 6325                      0    0.8809523809523809  0.23668507   0.17047647
# 6326                      0    1.0256410256410255  0.23880228   0.17117251
# 6327                      0    0.6013513513513513  0.23448437  0.095827565
#
#                  mean_zcr      liked
# 6323  0.14009860396888185  Metallica
# 6324  0.11901185884757384  Metallica
# 6325  0.11788901799841772  Metallica
# 6326  0.10669151338343882  Metallica
# 6327   0.1599450735100211  Metallica

# %%
df.to_pickle('metallica.pkl')
